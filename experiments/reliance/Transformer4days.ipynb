# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, Dropout, LayerNormalization,
    MultiHeadAttention, GlobalAveragePooling1D
)
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.losses import Huber
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
file_path = r"F:\Xai_traderx\experiments\reldemo.csv"
df = pd.read_csv(file_path)

# %%
selected_features = [
    # Price Action
    'Close', 'High', 'Low', 'Open',
    
    # Short-Term Trends
    'SMA_7', 'SMA_10', 'EMA_10',
    
    # Volatility & Volume
    'bb_upper', 'bb_lower', 'OBV', 'ATR',
    
    # Optional (Test Impact)
    'EMA_50', 'RSI_14', 'MACD_Hist'
]

# %%
df_selected = df[selected_features]

# %%
# 1. Separate features and target
features = df_selected
target = df[['next_close']]

# 2. Scale features and target separately
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(features)

scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(target)

# 3. Train-test split (no shuffle)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, shuffle=False, test_size=0.2)

# 4. Define lookback
lookback = 4

# 5. Sequence creation function
def create_sequence(X, y, lookback):
    Xs, ys = [], []
    for i in range(len(X) - lookback):
        Xs.append(X[i:(i + lookback)])
        ys.append(y[i + lookback])
    return np.array(Xs), np.array(ys)

# 6. Create sequences
X_train_seq, y_train_seq = create_sequence(X_train, y_train, lookback)
X_test_seq, y_test_seq = create_sequence(X_test, y_test, lookback)

print("Shape of X_train_seq:", X_train_seq.shape)
print("Shape of y_train_seq:", y_train_seq.shape)
print("Shape of X_test_seq:", X_test_seq.shape)
print("Shape of y_test_seq:", y_test_seq.shape)
# Out:
# Shape of X_train_seq: (577, 4, 14)
# Shape of y_train_seq: (577, 1)
# Shape of X_test_seq: (142, 4, 14)
# Shape of y_test_seq: (142, 1)

# %%
def transformer_model(input_shape, num_heads=4, dff=128, num_layers=2):
    inputs = Input(shape=input_shape)
    
    x = inputs
    for _ in range(num_layers):
        # Multi-Head Attention layer
        attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=64)(x, x)
        x = LayerNormalization()(x + attn_output)  
        
        # Feed-forward layer
        ff_output = Dense(dff, activation='relu')(x)
        ff_output = Dense(x.shape[-1])(ff_output)  # Project back to the original input shape
        x = LayerNormalization()(x + ff_output)  # Add & Normalize

    # Global Average Pooling
    x = GlobalAveragePooling1D()(x)
    
    # Fully connected output layer
    x = Dropout(0.2)(x)
    output = Dense(1)(x)

    # Define the model
    model = Model(inputs=inputs, outputs=output)
    return model

# Create the Transformer model
model = transformer_model(input_shape=(lookback, X_train_seq.shape[2]))

# Compile the model
optimizer = Nadam(learning_rate=1e-4)
model.compile(optimizer=optimizer, loss=Huber(), metrics=['mae'])

# Define callbacks
callbacks = [
    EarlyStopping(monitor='val_mae', patience=50, restore_best_weights=True),
    ModelCheckpoint('best_model_transformer.keras', save_best_only=True),
    ReduceLROnPlateau(monitor='val_mae', factor=0.5, patience=25, min_lr=1e-6)
]

# Fit the model
history = model.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=500,
    batch_size=1,
    callbacks=callbacks,
    shuffle=False,
    verbose=1
)

print("Training Completed..")
# Out:
# Epoch 1/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.2354 - mae: 0.5551 - val_loss: 0.0261 - val_mae: 0.1969 - learning_rate: 1.0000e-04
# Epoch 2/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0573 - mae: 0.2526 - val_loss: 0.0191 - val_mae: 0.1700 - learning_rate: 1.0000e-04
# Epoch 3/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0378 - mae: 0.2112 - val_loss: 0.0285 - val_mae: 0.1952 - learning_rate: 1.0000e-04
# Epoch 4/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0244 - mae: 0.1707 - val_loss: 0.0152 - val_mae: 0.1547 - learning_rate: 1.0000e-04
# Epoch 5/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0163 - mae: 0.1392 - val_loss: 0.0149 - val_mae: 0.1514 - learning_rate: 1.0000e-04
# Epoch 6/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0140 - mae: 0.1325 - val_loss: 0.0176 - val_mae: 0.1607 - learning_rate: 1.0000e-04
# Epoch 7/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0118 - mae: 0.1187 - val_loss: 0.0131 - val_mae: 0.1418 - learning_rate: 1.0000e-04
# Epoch 8/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0101 - mae: 0.1071 - val_loss: 0.0160 - val_mae: 0.1543 - learning_rate: 1.0000e-04
# Epoch 9/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0080 - mae: 0.0967 - val_loss: 0.0181 - val_mae: 0.1634 - learning_rate: 1.0000e-04
# Epoch 10/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0065 - mae: 0.0891 - val_loss: 0.0182 - val_mae: 0.1643 - learning_rate: 1.0000e-04
# Epoch 11/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0060 - mae: 0.0854 - val_loss: 0.0218 - val_mae: 0.1775 - learning_rate: 1.0000e-04
# Epoch 12/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0047 - mae: 0.0772 - val_loss: 0.0167 - val_mae: 0.1632 - learning_rate: 1.0000e-04
# Epoch 13/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0041 - mae: 0.0719 - val_loss: 0.0189 - val_mae: 0.1696 - learning_rate: 1.0000e-04
# Epoch 14/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0042 - mae: 0.0725 - val_loss: 0.0211 - val_mae: 0.1758 - learning_rate: 1.0000e-04
# Epoch 15/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0040 - mae: 0.0737 - val_loss: 0.0183 - val_mae: 0.1648 - learning_rate: 1.0000e-04
# Epoch 16/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0039 - mae: 0.0696 - val_loss: 0.0179 - val_mae: 0.1636 - learning_rate: 1.0000e-04
# Epoch 17/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0043 - mae: 0.0736 - val_loss: 0.0234 - val_mae: 0.1792 - learning_rate: 1.0000e-04
# Epoch 18/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0043 - mae: 0.0723 - val_loss: 0.0247 - val_mae: 0.1831 - learning_rate: 1.0000e-04
# Epoch 19/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0042 - mae: 0.0713 - val_loss: 0.0164 - val_mae: 0.1545 - learning_rate: 1.0000e-04
# Epoch 20/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0043 - mae: 0.0719 - val_loss: 0.0182 - val_mae: 0.1593 - learning_rate: 1.0000e-04
# Epoch 21/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0045 - mae: 0.0764 - val_loss: 0.0184 - val_mae: 0.1567 - learning_rate: 1.0000e-04
# Epoch 22/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0047 - mae: 0.0758 - val_loss: 0.0213 - val_mae: 0.1673 - learning_rate: 1.0000e-04
# Epoch 23/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0051 - mae: 0.0805 - val_loss: 0.0157 - val_mae: 0.1461 - learning_rate: 1.0000e-04
# Epoch 24/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0047 - mae: 0.0767 - val_loss: 0.0173 - val_mae: 0.1504 - learning_rate: 1.0000e-04
# Epoch 25/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0042 - mae: 0.0719 - val_loss: 0.0180 - val_mae: 0.1546 - learning_rate: 1.0000e-04
# Epoch 26/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0050 - mae: 0.0756 - val_loss: 0.0171 - val_mae: 0.1501 - learning_rate: 1.0000e-04
# Epoch 27/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0040 - mae: 0.0704 - val_loss: 0.0159 - val_mae: 0.1464 - learning_rate: 1.0000e-04
# Epoch 28/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0035 - mae: 0.0660 - val_loss: 0.0126 - val_mae: 0.1323 - learning_rate: 1.0000e-04
# Epoch 29/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0031 - mae: 0.0636 - val_loss: 0.0127 - val_mae: 0.1324 - learning_rate: 1.0000e-04
# Epoch 30/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0029 - mae: 0.0598 - val_loss: 0.0150 - val_mae: 0.1407 - learning_rate: 1.0000e-04
# Epoch 31/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0032 - mae: 0.0618 - val_loss: 0.0139 - val_mae: 0.1323 - learning_rate: 1.0000e-04
# Epoch 32/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0028 - mae: 0.0591 - val_loss: 0.0103 - val_mae: 0.1181 - learning_rate: 1.0000e-04
# Epoch 33/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0025 - mae: 0.0563 - val_loss: 0.0135 - val_mae: 0.1337 - learning_rate: 1.0000e-04
# Epoch 34/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0029 - mae: 0.0598 - val_loss: 0.0142 - val_mae: 0.1348 - learning_rate: 1.0000e-04
# Epoch 35/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0023 - mae: 0.0533 - val_loss: 0.0135 - val_mae: 0.1313 - learning_rate: 1.0000e-04
# Epoch 36/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0025 - mae: 0.0565 - val_loss: 0.0100 - val_mae: 0.1100 - learning_rate: 1.0000e-04
# Epoch 37/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0022 - mae: 0.0511 - val_loss: 0.0135 - val_mae: 0.1298 - learning_rate: 1.0000e-04
# Epoch 38/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0024 - mae: 0.0554 - val_loss: 0.0105 - val_mae: 0.1182 - learning_rate: 1.0000e-04
# Epoch 39/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0023 - mae: 0.0549 - val_loss: 0.0089 - val_mae: 0.1102 - learning_rate: 1.0000e-04
# Epoch 40/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0022 - mae: 0.0520 - val_loss: 0.0108 - val_mae: 0.1130 - learning_rate: 1.0000e-04
# Epoch 41/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0021 - mae: 0.0525 - val_loss: 0.0109 - val_mae: 0.1141 - learning_rate: 1.0000e-04
# Epoch 42/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0023 - mae: 0.0519 - val_loss: 0.0137 - val_mae: 0.1263 - learning_rate: 1.0000e-04
# Epoch 43/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0026 - mae: 0.0534 - val_loss: 0.0128 - val_mae: 0.1270 - learning_rate: 1.0000e-04
# Epoch 44/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0024 - mae: 0.0533 - val_loss: 0.0108 - val_mae: 0.1177 - learning_rate: 1.0000e-04
# Epoch 45/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0021 - mae: 0.0509 - val_loss: 0.0080 - val_mae: 0.1032 - learning_rate: 1.0000e-04
# Epoch 46/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0018 - mae: 0.0480 - val_loss: 0.0094 - val_mae: 0.1086 - learning_rate: 1.0000e-04
# Epoch 47/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0022 - mae: 0.0531 - val_loss: 0.0099 - val_mae: 0.1141 - learning_rate: 1.0000e-04
# Epoch 48/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0022 - mae: 0.0503 - val_loss: 0.0096 - val_mae: 0.1120 - learning_rate: 1.0000e-04
# Epoch 49/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0024 - mae: 0.0536 - val_loss: 0.0091 - val_mae: 0.1113 - learning_rate: 1.0000e-04
# Epoch 50/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0021 - mae: 0.0497 - val_loss: 0.0067 - val_mae: 0.0945 - learning_rate: 1.0000e-04
# Epoch 51/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0018 - mae: 0.0471 - val_loss: 0.0078 - val_mae: 0.1008 - learning_rate: 1.0000e-04
# Epoch 52/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0020 - mae: 0.0491 - val_loss: 0.0068 - val_mae: 0.0937 - learning_rate: 1.0000e-04
# Epoch 53/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0019 - mae: 0.0477 - val_loss: 0.0070 - val_mae: 0.0954 - learning_rate: 1.0000e-04
# Epoch 54/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0018 - mae: 0.0462 - val_loss: 0.0050 - val_mae: 0.0790 - learning_rate: 1.0000e-04
# Epoch 55/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0018 - mae: 0.0454 - val_loss: 0.0052 - val_mae: 0.0820 - learning_rate: 1.0000e-04
# Epoch 56/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0019 - mae: 0.0479 - val_loss: 0.0056 - val_mae: 0.0831 - learning_rate: 1.0000e-04
# Epoch 57/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0023 - mae: 0.0520 - val_loss: 0.0058 - val_mae: 0.0833 - learning_rate: 1.0000e-04
# Epoch 58/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0020 - mae: 0.0498 - val_loss: 0.0058 - val_mae: 0.0880 - learning_rate: 1.0000e-04
# Epoch 59/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0020 - mae: 0.0497 - val_loss: 0.0051 - val_mae: 0.0816 - learning_rate: 1.0000e-04
# Epoch 60/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0017 - mae: 0.0462 - val_loss: 0.0059 - val_mae: 0.0860 - learning_rate: 1.0000e-04
# Epoch 61/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0017 - mae: 0.0455 - val_loss: 0.0051 - val_mae: 0.0815 - learning_rate: 1.0000e-04
# Epoch 62/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0019 - mae: 0.0493 - val_loss: 0.0050 - val_mae: 0.0798 - learning_rate: 1.0000e-04
# Epoch 63/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0018 - mae: 0.0478 - val_loss: 0.0041 - val_mae: 0.0732 - learning_rate: 1.0000e-04
# Epoch 64/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0018 - mae: 0.0476 - val_loss: 0.0039 - val_mae: 0.0716 - learning_rate: 1.0000e-04
# Epoch 65/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0016 - mae: 0.0433 - val_loss: 0.0041 - val_mae: 0.0732 - learning_rate: 1.0000e-04
# Epoch 66/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0017 - mae: 0.0456 - val_loss: 0.0052 - val_mae: 0.0784 - learning_rate: 1.0000e-04
# Epoch 67/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0018 - mae: 0.0480 - val_loss: 0.0037 - val_mae: 0.0699 - learning_rate: 1.0000e-04
# Epoch 68/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0016 - mae: 0.0466 - val_loss: 0.0041 - val_mae: 0.0699 - learning_rate: 1.0000e-04
# Epoch 69/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0018 - mae: 0.0475 - val_loss: 0.0034 - val_mae: 0.0667 - learning_rate: 1.0000e-04
# Epoch 70/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0016 - mae: 0.0442 - val_loss: 0.0040 - val_mae: 0.0731 - learning_rate: 1.0000e-04
# Epoch 71/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0016 - mae: 0.0446 - val_loss: 0.0039 - val_mae: 0.0722 - learning_rate: 1.0000e-04
# Epoch 72/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0017 - mae: 0.0457 - val_loss: 0.0034 - val_mae: 0.0657 - learning_rate: 1.0000e-04
# Epoch 73/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0017 - mae: 0.0471 - val_loss: 0.0035 - val_mae: 0.0686 - learning_rate: 1.0000e-04
# Epoch 74/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0016 - mae: 0.0447 - val_loss: 0.0042 - val_mae: 0.0748 - learning_rate: 1.0000e-04
# Epoch 75/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0015 - mae: 0.0433 - val_loss: 0.0031 - val_mae: 0.0626 - learning_rate: 1.0000e-04
# Epoch 76/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0015 - mae: 0.0436 - val_loss: 0.0033 - val_mae: 0.0670 - learning_rate: 1.0000e-04
# Epoch 77/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0015 - mae: 0.0425 - val_loss: 0.0046 - val_mae: 0.0783 - learning_rate: 1.0000e-04
# Epoch 78/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0424 - val_loss: 0.0042 - val_mae: 0.0733 - learning_rate: 1.0000e-04
# Epoch 79/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0017 - mae: 0.0471 - val_loss: 0.0038 - val_mae: 0.0676 - learning_rate: 1.0000e-04
# Epoch 80/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0017 - mae: 0.0464 - val_loss: 0.0037 - val_mae: 0.0710 - learning_rate: 1.0000e-04
# Epoch 81/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0016 - mae: 0.0462 - val_loss: 0.0035 - val_mae: 0.0674 - learning_rate: 1.0000e-04
# Epoch 82/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0016 - mae: 0.0452 - val_loss: 0.0035 - val_mae: 0.0675 - learning_rate: 1.0000e-04
# Epoch 83/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0015 - mae: 0.0455 - val_loss: 0.0030 - val_mae: 0.0629 - learning_rate: 1.0000e-04
# Epoch 84/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0015 - mae: 0.0441 - val_loss: 0.0028 - val_mae: 0.0602 - learning_rate: 1.0000e-04
# Epoch 85/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0424 - val_loss: 0.0032 - val_mae: 0.0656 - learning_rate: 1.0000e-04
# Epoch 86/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0434 - val_loss: 0.0038 - val_mae: 0.0705 - learning_rate: 1.0000e-04
# Epoch 87/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0015 - mae: 0.0446 - val_loss: 0.0032 - val_mae: 0.0654 - learning_rate: 1.0000e-04
# Epoch 88/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0013 - mae: 0.0400 - val_loss: 0.0042 - val_mae: 0.0743 - learning_rate: 1.0000e-04
# Epoch 89/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0416 - val_loss: 0.0027 - val_mae: 0.0617 - learning_rate: 1.0000e-04
# Epoch 90/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0432 - val_loss: 0.0038 - val_mae: 0.0713 - learning_rate: 1.0000e-04
# Epoch 91/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0015 - mae: 0.0439 - val_loss: 0.0039 - val_mae: 0.0715 - learning_rate: 1.0000e-04
# Epoch 92/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0423 - val_loss: 0.0029 - val_mae: 0.0627 - learning_rate: 1.0000e-04
# Epoch 93/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0015 - mae: 0.0441 - val_loss: 0.0034 - val_mae: 0.0689 - learning_rate: 1.0000e-04
# Epoch 94/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0418 - val_loss: 0.0045 - val_mae: 0.0804 - learning_rate: 1.0000e-04
# Epoch 95/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0431 - val_loss: 0.0036 - val_mae: 0.0685 - learning_rate: 1.0000e-04
# Epoch 96/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0015 - mae: 0.0436 - val_loss: 0.0037 - val_mae: 0.0703 - learning_rate: 1.0000e-04
# Epoch 97/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0015 - mae: 0.0429 - val_loss: 0.0035 - val_mae: 0.0681 - learning_rate: 1.0000e-04
# Epoch 98/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0014 - mae: 0.0429 - val_loss: 0.0035 - val_mae: 0.0685 - learning_rate: 1.0000e-04
# Epoch 99/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0015 - mae: 0.0445 - val_loss: 0.0041 - val_mae: 0.0738 - learning_rate: 1.0000e-04
# Epoch 100/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0013 - mae: 0.0399 - val_loss: 0.0027 - val_mae: 0.0607 - learning_rate: 1.0000e-04
# Epoch 101/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0013 - mae: 0.0409 - val_loss: 0.0041 - val_mae: 0.0757 - learning_rate: 1.0000e-04
# Epoch 102/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0013 - mae: 0.0402 - val_loss: 0.0029 - val_mae: 0.0652 - learning_rate: 1.0000e-04
# Epoch 103/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0015 - mae: 0.0422 - val_loss: 0.0028 - val_mae: 0.0614 - learning_rate: 1.0000e-04
# Epoch 104/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0409 - val_loss: 0.0038 - val_mae: 0.0709 - learning_rate: 1.0000e-04
# Epoch 105/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0013 - mae: 0.0403 - val_loss: 0.0029 - val_mae: 0.0636 - learning_rate: 1.0000e-04
# Epoch 106/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0011 - mae: 0.0367 - val_loss: 0.0043 - val_mae: 0.0752 - learning_rate: 1.0000e-04
# Epoch 107/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0013 - mae: 0.0397 - val_loss: 0.0046 - val_mae: 0.0792 - learning_rate: 1.0000e-04
# Epoch 108/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0012 - mae: 0.0389 - val_loss: 0.0034 - val_mae: 0.0672 - learning_rate: 1.0000e-04
# Epoch 109/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0011 - mae: 0.0378 - val_loss: 0.0042 - val_mae: 0.0745 - learning_rate: 1.0000e-04
# Epoch 110/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0402 - val_loss: 0.0054 - val_mae: 0.0862 - learning_rate: 5.0000e-05
# Epoch 111/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0404 - val_loss: 0.0058 - val_mae: 0.0904 - learning_rate: 5.0000e-05
# Epoch 112/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0015 - mae: 0.0419 - val_loss: 0.0045 - val_mae: 0.0781 - learning_rate: 5.0000e-05
# Epoch 113/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0011 - mae: 0.0364 - val_loss: 0.0041 - val_mae: 0.0745 - learning_rate: 5.0000e-05
# Epoch 114/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0011 - mae: 0.0369 - val_loss: 0.0041 - val_mae: 0.0759 - learning_rate: 5.0000e-05
# Epoch 115/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0011 - mae: 0.0366 - val_loss: 0.0044 - val_mae: 0.0785 - learning_rate: 5.0000e-05
# Epoch 116/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0011 - mae: 0.0382 - val_loss: 0.0040 - val_mae: 0.0744 - learning_rate: 5.0000e-05
# Epoch 117/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0010 - mae: 0.0355 - val_loss: 0.0050 - val_mae: 0.0832 - learning_rate: 5.0000e-05
# Epoch 118/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0010 - mae: 0.0365 - val_loss: 0.0036 - val_mae: 0.0705 - learning_rate: 5.0000e-05
# Epoch 119/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0010 - mae: 0.0354 - val_loss: 0.0040 - val_mae: 0.0732 - learning_rate: 5.0000e-05
# Epoch 120/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0011 - mae: 0.0367 - val_loss: 0.0049 - val_mae: 0.0828 - learning_rate: 5.0000e-05
# Epoch 121/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0011 - mae: 0.0365 - val_loss: 0.0056 - val_mae: 0.0910 - learning_rate: 5.0000e-05
# Epoch 122/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 9.2798e-04 - mae: 0.0345 - val_loss: 0.0028 - val_mae: 0.0638 - learning_rate: 5.0000e-05
# Epoch 123/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0010 - mae: 0.0361 - val_loss: 0.0038 - val_mae: 0.0726 - learning_rate: 5.0000e-05
# Epoch 124/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.9809e-04 - mae: 0.0353 - val_loss: 0.0046 - val_mae: 0.0783 - learning_rate: 5.0000e-05
# Epoch 125/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.7168e-04 - mae: 0.0347 - val_loss: 0.0038 - val_mae: 0.0716 - learning_rate: 5.0000e-05
# Epoch 126/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.5337e-04 - mae: 0.0346 - val_loss: 0.0041 - val_mae: 0.0757 - learning_rate: 5.0000e-05
# Epoch 127/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.4218e-04 - mae: 0.0345 - val_loss: 0.0043 - val_mae: 0.0782 - learning_rate: 5.0000e-05
# Epoch 128/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.0234e-04 - mae: 0.0331 - val_loss: 0.0036 - val_mae: 0.0714 - learning_rate: 5.0000e-05
# Epoch 129/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 8.7175e-04 - mae: 0.0330 - val_loss: 0.0033 - val_mae: 0.0695 - learning_rate: 5.0000e-05
# Epoch 130/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.2525e-04 - mae: 0.0347 - val_loss: 0.0043 - val_mae: 0.0773 - learning_rate: 5.0000e-05
# Epoch 131/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0010 - mae: 0.0356 - val_loss: 0.0043 - val_mae: 0.0772 - learning_rate: 5.0000e-05
# Epoch 132/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.2096e-04 - mae: 0.0335 - val_loss: 0.0045 - val_mae: 0.0782 - learning_rate: 5.0000e-05
# Epoch 133/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 9.4023e-04 - mae: 0.0339 - val_loss: 0.0035 - val_mae: 0.0706 - learning_rate: 5.0000e-05
# Epoch 134/500
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.3268e-04 - mae: 0.0337 - val_loss: 0.0034 - val_mae: 0.0691 - learning_rate: 5.0000e-05
# Training Completed..

# %%
test_loss, test_mae = model.evaluate(X_test_seq, y_test_seq)
print(f"Test Loss: {test_loss}")
print(f"Test MAE: {test_mae}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0025 - mae: 0.0577
# Test Loss: 0.0028294844087213278
# Test MAE: 0.06017225608229637

# %%
y_pred_scaled = model.predict(X_test_seq)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %%
# Reshape if needed
y_pred_scaled = y_pred_scaled.reshape(-1, 1)
y_test_seq = y_test_seq.reshape(-1, 1)

# Inverse transform
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_true = scaler_y.inverse_transform(y_test_seq)

# %%
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)
percentage_error = (mae / np.mean(y_true)) * 100
print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R2 Score: {r2:.4f}")
print(f"Percentage Error: {percentage_error:.2f}%")
# Out:
# MAE: 41.7824
# RMSE: 52.2354
# R2 Score: 0.8160
# Percentage Error: 3.08%
