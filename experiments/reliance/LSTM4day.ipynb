# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, Input,BatchNormalization
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.losses import Huber
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import tensorflow.keras.backend as K
import tensorflow as tf

# %%
file_path = r"F:\Xai_traderx\data\processed\reliance_processed.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#          Date       Close        High         Low        Open     Volume  \
# 0  2020-07-15  845.291199  907.083664  824.204808  888.357962  139669773
# 1  2020-07-16  845.016235  856.751295  830.828700  846.666456   60961724
# 2  2020-07-17  876.324951  880.129674  842.540773  845.749610   49726765
# 3  2020-07-20  880.083801  885.630471  870.801218  879.121193   36592938
# 4  2020-07-21  903.760254  906.258562  887.693335  888.839335   42173371
#
#    Close_Return_1D  Close_Return_3D    Return  High_Low_Spread  ...  \
# 0        -0.038080        -0.018131 -0.038080         0.098048  ...
# 1        -0.000325        -0.047338 -0.000325         0.030677  ...
# 2         0.037051        -0.002765  0.037051         0.042894  ...
# 3         0.004289         0.041160  0.004289         0.016850  ...
# 4         0.026902         0.069518  0.026902         0.020542  ...
#
#      bb_upper    bb_lower  bb_width  Bollinger_%B  bear_score  bull_strength  \
# 0  885.494315  748.906497  0.167141      0.705661         0.3            0.0
# 1  885.040723  757.955108  0.154700      0.685059         0.0            0.0
# 2  892.604734  757.372542  0.163920      0.879616         0.0            0.0
# 3  899.803924  758.138062  0.170894      0.860798         0.0            0.0
# 4  910.328241  759.103565  0.181169      0.956568         0.0            0.0
#
#    bear_strength   Momentum  Volatility  next_close
# 0            0.0  21.086426   32.846620  845.016235
# 1            0.0   8.778442   31.822700  876.324951
# 2            0.0  15.425171   31.281957  880.083801
# 3            0.0  -6.921875   28.300401  903.760254
# 4            0.0  25.005798   28.440126  918.635376
#
# [5 rows x 34 columns]
